# %% [markdown]
# # Consensus V2 Side Training (YCrCb)
#
# Цель: обучать side-модель в YCrCb.
#
# - Входы: `warp_ycc (3)` + `lidar_trust (1)` + `mean_t0t1_ycc (3)` = **7 каналов**
# - Таргет: `target_ycc (3)`
# - Лосс: **MSE в YCrCb**
#
# Mirror policy:
# - На диске всё остаётся в camera-space
# - Для `left_fwd` / `right_bwd` flip делаем только на этапе формирования input tensor
# - При инференсе выход нужно вернуть обратно в camera-space

# %%
from __future__ import annotations

import json
import random
from dataclasses import dataclass
from pathlib import Path

import cv2
import numpy as np
import torch
from PIL import Image
from torch.utils.data import DataLoader, Dataset

from consensus_kit import ConsensusConfig, ConsensusUNet, discover_samples
from lib.lidar_density_mask import lidar_rife_blend_maps
from ya_paths import BAKED_ROOT, EGO_MASKS_APPROVED, TRAIN_SPLIT, WARPS_ROOT, CV_ROOT

# %%
SIDE_CAMERAS = ("left_fwd", "right_fwd", "left_bwd", "right_bwd")
MIRROR_CAMERAS = ("left_fwd", "right_bwd")

@dataclass
class V2Cfg:
    image_h: int = 544
    image_w: int = 1024
    in_channels: int = 7
    base_channels: int = 32
    batch_size: int = 12
    num_workers: int = 0
    lr: float = 2e-4
    epochs: int = 8
    val_fraction: float = 0.16
    seed: int = 42
    trust_zone_min: float = 0.12
    trust_cache_root: Path = CV_ROOT / "precomputed_lidar_trust" / "train"
    dataset_root: Path = TRAIN_SPLIT
    baked_root: Path = BAKED_ROOT / "train"
    warps_root: Path = WARPS_ROOT / "train"

CFG = V2Cfg()
print(CFG)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def to_ycrcb_u8(rgb_u8: np.ndarray) -> np.ndarray:
    return cv2.cvtColor(rgb_u8, cv2.COLOR_RGB2YCrCb)

def load_rgb(path: Path, hw: tuple[int, int]) -> np.ndarray:
    arr = np.array(Image.open(path).convert("RGB"), dtype=np.uint8)
    h, w = hw
    if arr.shape[:2] != (h, w):
        arr = cv2.resize(arr, (w, h), interpolation=cv2.INTER_LINEAR)
    return arr

def load_warp(path: Path, hw: tuple[int, int]) -> np.ndarray:
    arr = np.load(path).astype(np.float32)
    if arr.ndim == 3 and arr.shape[0] == 3:
        arr = np.clip(arr.transpose(1, 2, 0), 0.0, 1.0)
    arr = (arr * 255.0).astype(np.uint8)
    h, w = hw
    if arr.shape[:2] != (h, w):
        arr = cv2.resize(arr, (w, h), interpolation=cv2.INTER_LINEAR)
    return arr

def flip_h(*arrays):
    return tuple(a[:, ::-1].copy() for a in arrays)

class ConsensusV2SideDataset(Dataset):
    def __init__(self, baked_dirs: list[Path], cfg: V2Cfg, augment: bool = False):
        self.dirs = [Path(x) for x in baked_dirs]
        self.cfg = cfg
        self.augment = augment

    def __len__(self):
        return len(self.dirs)

    def _load_trust(self, src_dir: Path, sid: str, cam: str, hw: tuple[int, int]) -> np.ndarray:
        cache = self.cfg.trust_cache_root / sid / "lidar_trust.npy"
        if cache.is_file():
            t = np.load(cache).astype(np.float32)
            if t.shape == hw:
                return np.clip(t, 0.0, 1.0)

        maps = lidar_rife_blend_maps(src_dir, cam, hw, spread_radius_fine=3.0, spread_blur_fine=1.0, zone_min=self.cfg.trust_zone_min)
        t = np.clip(maps["lidar_trust"].astype(np.float32), 0.0, 1.0)
        cache.parent.mkdir(parents=True, exist_ok=True)
        np.save(cache, t.astype(np.float32))
        return t

    def __getitem__(self, idx):
        baked_dir = self.dirs[idx]
        meta = json.loads((baked_dir / "meta.json").read_text(encoding="utf-8"))
        sid = meta["sample_id"]
        cam = meta["camera"]
        src = Path(meta.get("source_dir", self.cfg.dataset_root / sid))
        hw = (self.cfg.image_h, self.cfg.image_w)

        warp_rgb = load_warp(self.cfg.warps_root / sid / "consensus_raw.npy", hw)
        t0 = load_rgb(src / "input" / "t0" / f"{cam}.jpg", hw)
        t1 = load_rgb(src / "input" / "t1" / f"{cam}.jpg", hw)
        target_rgb = load_rgb(src / "target" / f"{cam}.jpg", hw)
        mean_rgb = ((t0.astype(np.float32) + t1.astype(np.float32)) * 0.5).astype(np.uint8)
        trust = self._load_trust(src, sid, cam, hw)

        warp_ycc = to_ycrcb_u8(warp_rgb).astype(np.float32) / 255.0
        mean_ycc = to_ycrcb_u8(mean_rgb).astype(np.float32) / 255.0
        target_ycc = to_ycrcb_u8(target_rgb).astype(np.float32) / 255.0

        mirrored = cam in MIRROR_CAMERAS
        if mirrored:
            warp_ycc, mean_ycc, target_ycc, trust = flip_h(warp_ycc, mean_ycc, target_ycc, trust)

        x = np.concatenate([warp_ycc, trust[..., None], mean_ycc], axis=-1)
        base_init = warp_ycc
        effective_mask = np.ones((hw[0], hw[1]), dtype=np.float32)

        to_chw = lambda a: torch.from_numpy(a.transpose(2, 0, 1)).contiguous().float()
        to_1chw = lambda a: torch.from_numpy(a)[None].contiguous().float()
        return {
            "inputs": to_chw(x),
            "base_init": to_chw(base_init),
            "effective_mask": to_1chw(effective_mask),
            "target": to_chw(target_ycc),
            "sample_id": sid,
            "camera": cam,
            "mirrored": mirrored,
        }

# %%
seed_everything(CFG.seed)

disc_cfg = ConsensusConfig(
    dataset_root=str(CFG.dataset_root),
    consensus_root=str(CFG.warps_root),
    baked_root=str(CFG.baked_root),
    rife_root=str(CV_ROOT / "rife_predictions_v5" / "train"),
    ego_masks_root=str(EGO_MASKS_APPROVED),
    allowed_cameras=SIDE_CAMERAS,
    image_h=CFG.image_h,
    image_w=CFG.image_w,
)

all_samples = discover_samples(disc_cfg)
print(f"discover_samples: {len(all_samples)}")
rng = np.random.RandomState(CFG.seed)
idx = np.arange(len(all_samples))
rng.shuffle(idx)
n_val = max(1, int(len(all_samples) * CFG.val_fraction))
val_idx = idx[:n_val]
train_idx = idx[n_val:]
train_dirs = [all_samples[i] for i in train_idx]
val_dirs = [all_samples[i] for i in val_idx]
print(f"train={len(train_dirs)} val={len(val_dirs)}")

train_ds = ConsensusV2SideDataset(train_dirs, CFG, augment=True)
val_ds = ConsensusV2SideDataset(val_dirs, CFG, augment=False)
train_loader = DataLoader(train_ds, batch_size=CFG.batch_size, shuffle=True, num_workers=CFG.num_workers)
val_loader = DataLoader(val_ds, batch_size=CFG.batch_size, shuffle=False, num_workers=CFG.num_workers)
b = next(iter(train_loader))
print("inputs:", tuple(b["inputs"].shape), "target:", tuple(b["target"].shape))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
model = ConsensusUNet(in_channels=CFG.in_channels, base_channels=CFG.base_channels, out_channels=3).to(device)
opt = torch.optim.AdamW(model.parameters(), lr=CFG.lr)
criterion = torch.nn.MSELoss()

def run_epoch(loader, train: bool):
    model.train(train)
    losses = []
    for batch in loader:
        inp = batch["inputs"].to(device)
        base = batch["base_init"].to(device)
        msk = batch["effective_mask"].to(device)
        tgt = batch["target"].to(device)
        with torch.set_grad_enabled(train):
            out = model(inp, msk, base)["pred"].float()
            loss = criterion(out, tgt)
            if train:
                opt.zero_grad(set_to_none=True)
                loss.backward()
                opt.step()
        losses.append(float(loss.detach().cpu()))
    return float(np.mean(losses)) if losses else 0.0

best_val = 1e9
save_dir = Path("artifacts/checkpoints/consensus_side_v2")
save_dir.mkdir(parents=True, exist_ok=True)
ckpt_best = save_dir / "consensus_v2_side_best.pt"

for ep in range(1, CFG.epochs + 1):
    tr = run_epoch(train_loader, train=True)
    va = run_epoch(val_loader, train=False)
    print(f"epoch {ep:02d}: train_mse={tr:.6f}  val_mse={va:.6f}")
    if va < best_val:
        best_val = va
        torch.save({
            "epoch": ep,
            "model": model.state_dict(),
            "opt": opt.state_dict(),
            "cfg": vars(CFG),
            "best_val_mse": best_val,
            "color_space": "YCrCb",
            "inputs": ["warp_ycc(3)", "lidar_trust(1)", "mean_t0t1_ycc(3)"],
            "target": "target_ycc(3)",
            "loss": "MSE",
        }, ckpt_best)
        print("  saved best ->", ckpt_best)

print("done. best_val_mse=", best_val)

# %% [markdown]
# ## Debug: запуск train/eval из ноутбука
#
# Ниже — утилитарные ячейки для отладки и честного сравнения `ycrcb` vs `rgb` на одном протоколе.
#
# - запускают внешние скрипты,
# - сохраняют метрики в `artifacts/preview/.../metrics.json`,
# - собирают короткую сравнительную таблицу прямо в ноутбуке.

# %%
import json
import subprocess
from pathlib import Path

REPO = Path(r"C:/Users/adel/Documents/GitHub/YA-")
TRAIN_SCRIPT = REPO / "scripts/training/train_v2_ycrcb_side.py"
EVAL_SCRIPT = REPO / "scripts/training/eval_v2_ycrcb_side.py"


def run_cmd(cmd: list[str]):
    print("$", " ".join(cmd))
    return subprocess.run(cmd, cwd=str(REPO), check=True)


def train_and_eval(color_space: str, limit=100, epochs=3, batch_size=10, device="cuda", save_n=8):
    ckpt = REPO / f"artifacts/checkpoints/consensus_side_v2/consensus_v2_side_100_{color_space}_best.pt"
    out_dir = REPO / f"artifacts/preview/consensus_v2_side_eval_{color_space}"

    run_cmd([
        "python", str(TRAIN_SCRIPT),
        "--limit", str(limit),
        "--epochs", str(epochs),
        "--batch-size", str(batch_size),
        "--device", device,
        "--color-space", color_space,
    ])

    run_cmd([
        "python", str(EVAL_SCRIPT),
        "--ckpt", str(ckpt),
        "--color-space", color_space,
        "--limit", str(limit),
        "--save-n", str(save_n),
        "--batch-size", "8",
        "--device", device,
        "--out-dir", str(out_dir),
    ])

    metrics_path = out_dir / "metrics.json"
    if metrics_path.is_file():
        metrics = json.loads(metrics_path.read_text(encoding="utf-8"))
        print(f"\n[{color_space}] MSE_RGB={metrics['metrics']['mse_rgb_mean']:.6f}  PSNR_RGB={metrics['metrics']['psnr_rgb_mean']:.3f} dB")
        return metrics
    print("metrics.json not found:", metrics_path)
    return None


# Примеры ручного запуска:
# m_ycc = train_and_eval("ycrcb", limit=100, epochs=3, batch_size=10, device="cuda")
# m_rgb = train_and_eval("rgb", limit=100, epochs=3, batch_size=10, device="cuda")


def compare_saved_metrics():
    paths = {
        "ycrcb": REPO / "artifacts/preview/consensus_v2_side_eval_ycrcb/metrics.json",
        "rgb": REPO / "artifacts/preview/consensus_v2_side_eval_rgb/metrics.json",
    }
    rows = []
    for k, p in paths.items():
        if p.is_file():
            m = json.loads(p.read_text(encoding="utf-8"))
            rows.append((k, m["metrics"]["mse_rgb_mean"], m["metrics"]["psnr_rgb_mean"], m["metrics"]["mse_ycc_mean"], m["metrics"]["psnr_ycc_mean"]))

    if not rows:
        print("Нет metrics.json для сравнения")
        return

    print("color_space | mse_rgb | psnr_rgb | mse_ycc | psnr_ycc")
    for r in rows:
        print(f"{r[0]:10s} | {r[1]:.6f} | {r[2]:.3f} | {r[3]:.6f} | {r[4]:.3f}")


# compare_saved_metrics()
